# %%
# Configuração
CATALOGO = "v_credit"
SCHEMA_GOLD = "gold"
SCHEMA_CURATED = "curated"

# %%
spark.sql(f"""
CREATE OR REPLACE VIEW {CATALOGO}.{SCHEMA_CURATED}.vw_ft_atendimento_geral AS
SELECT * FROM {CATALOGO}.{SCHEMA_GOLD}.ft_atendimento_geral
""")
