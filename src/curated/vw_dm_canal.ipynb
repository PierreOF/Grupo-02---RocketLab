# %%
CATALOGO = "v_credit"
SCHEMA_GOLD = "gold"
SCHEMA_CURATED = "curated"

# %% [markdown]
# ### Criacao de View Curated
# Cria view 1:1 que aponta para dm_canal (Gold).
#
# **Proposito**: Camada de isolamento para consumo externo (Power BI).

# %% [markdown]
# ### Configuracao
# Define catalogo e schemas (Gold origem, Curated destino).

# %%
spark.sql(f"CREATE OR REPLACE VIEW {CATALOGO}.{SCHEMA_CURATED}.vw_dm_canal AS SELECT * FROM {CATALOGO}.{SCHEMA_GOLD}.dm_canal")
