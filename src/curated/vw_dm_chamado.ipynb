# %%
# Configuração
CATALOGO = "v_credit"
SCHEMA_GOLD = "gold"
SCHEMA_CURATED = "curated"

# %%
spark.sql(f"CREATE OR REPLACE VIEW {CATALOGO}.{SCHEMA_CURATED}.vw_dm_chamado AS SELECT * FROM {CATALOGO}.{SCHEMA_GOLD}.dm_chamado")
